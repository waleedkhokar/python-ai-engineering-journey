# %%
import pandas as pd

data = {
    "Name": ["Ali", "Ahmed", "Sara", "Waleed"],
    "Age": [22, 25, 23, 24],
    "Salary": [50000, 70000, 60000, 80000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Age  Salary
# 0     Ali   22   50000
# 1   Ahmed   25   70000
# 2    Sara   23   60000
# 3  Waleed   24   80000

# %%
df.to_csv("employees.csv", index=False)

# %%
df = pd.read_csv("employees.csv")

print(df)
# Out:
#      Name  Age  Salary
# 0     Ali   22   50000
# 1   Ahmed   25   70000
# 2    Sara   23   60000
# 3  Waleed   24   80000

# %%
# df.to_excel("employees.xlsx", index=False)

# %%
# df = pd.read_excel("employes.xlsx")

# print(df)

# %%
df.to_json("employees.json", orient="records")

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Ahmed", "Sara"],
    "Age": [22, 25, 23],
    "Salary": [50000, 70000, 60000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Salary
# 0    Ali   22   50000
# 1  Ahmed   25   70000
# 2   Sara   23   60000

# %%
print(df.dtypes)
# Out:
# Name        str
# Age       int64
# Salary    int64
# dtype: object

# %%
print(df["Age"].dtype)
# Out:
# int64

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Ahmed", "Usman", "Waleed"],
    "Age": [22, 25, None, 24],
    "City": ["Lahore", "Islamabad", "Rawalpindi", None]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name   Age        City
# 0     Ali  22.0      Lahore
# 1   Ahmed  25.0   Islamabad
# 2   Usman   NaN  Rawalpindi
# 3  Waleed  24.0         NaN

# %%
df.isnull()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False  False   True

# %%
print(df.isnull())
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False  False   True

# %%
print(df.isnull().sum())
# Out:
# Name    0
# Age     1
# City    1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     1
# City    1
# dtype: int64

# %%
print(df[df.isnull().any(axis=1)])
# Out:
#      Name   Age        City
# 2   Usman   NaN  Rawalpindi
# 3  Waleed  24.0         NaN

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Ali", "Ahmed", "Usman"],
    "Age": [22, 25, 23],
    "Salary": [50000.5, 60000.0, 55000.5],
    "IsActive": [True, False, True]
})

print(df.dtypes)
# Out:
# Name            str
# Age           int64
# Salary      float64
# IsActive       bool
# dtype: object
