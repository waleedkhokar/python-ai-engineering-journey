# %%
import seaborn as sns

sns.lineplot(x=x, y=y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5]
sales = [100, 150, 120, 180, 220]

sns.lineplot(x=days, y=sales)

plt.show()

# %%
sns.set_theme()

sns.lineplot(data=df, x="day", y="sales")

plt.show()

# %%
df = pd.DataFrame({
    "experience": [1, 2, 3, 5, 7, 10],
    "salary": [40, 45, 55, 70, 90, 120]
})

# %%
sns.scatterplot(
    data=df,
    x="experience",
    y="salary"
)

plt.show()

# %%
df = pd.DataFrame({
    "experience": [1, 2, 3, 5, 7, 10],
    "salary": [40, 45, 55, 70, 90, 120],
    "department": ["IT", "HR", "IT", "HR", "IT", "HR"]
})

# %%
df = pd.DataFrame({
    "experience": [1, 2, 3, 5, 7, 10],
    "salary": [40, 45, 55, 70, 90, 120],
    "department": ["IT", "HR", "IT", "HR", "IT", "HR"]
})

# %%
sns.scatterplot(
    data=df,
    x="experience",
    y="salary",
    hue="department",
    style="department"
)

plt.show()

# %%
df = pd.DataFrame({
    "department": ["IT", "HR", "Finance"],
    "employees": [50, 30, 20]
})

# %%
sns.barplot(
    data=df,
    x="department",
    y="employees"
)

plt.show()

# %%
sns.histplot(
    data=df,
    x="salary"
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5]
sales = [100, 150, 120, 180, 220]

sns.set_theme()

sns.lineplot(x=days, y=sales)

plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5]
sales = [100, 150, 120, 180, 220]

sns.set_style("whitegrid")

sns.lineplot(x=days, y=sales)

plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5]
sales = [100, 150, 120, 180, 220]

sns.set_style("darkgrid")

sns.lineplot(x=days, y=sales)

plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5]
sales = [100, 150, 120, 180, 220]

sns.set_style("dark")

sns.lineplot(x=days, y=sales)

plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "experience": [1, 2, 3, 5, 7, 10],
    "salary": [40, 45, 55, 70, 90, 120]
})

sns.set_style("whitegrid")

sns.scatterplot(
    data=df,
    x="experience",
    y="salary"
)

plt.title("Experience vs Salary")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("employees.json")

# Theme
sns.set_theme()

# Plot
sns.scatterplot(
    data=df,
    x="feature",
    y="target"
)

# Customize
plt.title("Feature vs Target")
plt.xlabel("Feature")
plt.ylabel("Target")

plt.show()
