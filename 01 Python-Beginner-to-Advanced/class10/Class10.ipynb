# %% [markdown]
# # Function
# * pre-defined function
#     * provided by in language
# * user-defined function
#     * custom function
# ## Similar properties on both types
# * Return and non-return function
#     * we can assign this function output in any variable
#   * None-Return
#     * Only run we can't assign value to number
#
# ## Components
# * function declaration
# * function body
# * function calling
#
# ### Syntax function
# '''
# def function_name(param1:type, param2:type)> retuenType
# function_body
# function_name(arg1,arg2)
# '''

# %% [markdown]
# # Predefine Function
# * print
# * len
# * dir
# * chr
# * ord
# * exec

# %% [markdown]
# # Return and non-return type

# %%
a: str = print("pakistan")
# Out:
# pakistan
