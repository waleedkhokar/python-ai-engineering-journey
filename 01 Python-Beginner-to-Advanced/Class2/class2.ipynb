# %% [markdown]
# # 📘 Class 2: Strings in Python
#
# > **Date: January 2, 2024** 🎯
# >
# > Day 2 of my Python journey — mastering strings, the most used data type!
#
# ---
#
# ## 🎯 What I Learned in Class 2
#
# - What are strings & how to create them
# - String methods (46 built-in methods!)
# - String formatting (f-strings, `.format()`)
# - Escape characters (`\n`, `\t`, `\b`)
# - String concatenation
# - Whitespace handling (`strip`, `lstrip`, `rstrip`)
# - Type conversion (`str()`, `int()`)
#
# ---
#
# ## 🧵 What is a String?
#
# A **string** is a sequence of characters wrapped in quotes.
#
# ### 4 Ways to Create Strings
#
# ```python
# 'string text'      # single quotes
# "string text"      # double quotes
# '''string text'''  # triple single quotes
# """string text"""  # triple double quotes

# %%
name : str = "Muhammad Qadun"
print(type(name))   # <class 'str'>
print(name)         # Muhammad Qadun
# Out:
# <class 'str'>
# Muhammad Qadun

# %% [markdown]
# #tuj

# %%
name : any = "pakistan"
Number : int = '7'
print(name)
print(type(name))
print(id(name)) #physical address
print([i for i in dir(name) if "__" not in i]) #methods and attributes
print
# Out:
# pakistan
# <class 'str'>
# 4567719088
# ['capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
name : str = "Waleed Khooookhar"

print(name.capitalize())   # Waleed khooookhar
print(name.lower())        # waleed khooookhar
print(name.title())        # Waleed Khooookhar
# Out:
# Waleed khooookhar
# waleed khooookhar
# Waleed Khooookhar

# %%
print(name)
# Out:
# Waleed Khooookhar

# %% [markdown]
# #Boundries

# %%
'string text' ,  "string text" ,   '''string text''' , """  string text """
name : str = "Muhammad Qadun"
print(type(name))
print(name)
# Out:
# <class 'str'>
# Muhammad Qadun

# %%
'string text' ,  "string text" ,   '''string text''' , """  string text """
name : str = 'Muhammad Qadun'
print(type(name))
print(name)
# Out:
# <class 'str'>
# Muhammad Qadun

# %%
name = "Waleed"
education = "University"
age = 20

# ⚠️ Must convert int to str!
card = "PIAIC Card\nStudent: " + name + "\nAge: " + str(age)
print(card)
# Out:
# PIAIC Card
# Student: Waleed
# Age: 20

# %%
'string text' ,  "string text" ,   '''string text''' , """  string text """
tr : str = "University"
age : int = 20
name : str = "PIAIC card and/nfather's card: " + tr + "/nage:" +age

print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 'string text' ,  "string text" ,   '''string text''' , """  string text """
#       2 tr : str = "University"
#       3 age : int = 20
# ----> 4 name : str = "PIAIC card and/nfather's card: " + tr + "/nage:" +age
#       5
#       6 print(name)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name : str = "Waleed"
education : str = "UNiverstity"
age : int = 20
card : str = "PIAIC Card \n Students name: " + name +\
"\nAge: " + str(age) + "\n"
print(card)
# Out:
# PIAIC Card
#  Students name: Waleed
# Age: 20

# %%
print("line\nline")
# Out:
# line
# line

# %%
"a" + str(7)
# Out:
# 'a7'

# %%
name = "Waleed khokhar"
education = "BSCS"
age = 20

# With named placeholders
card = """
PIAIC card
Student nam: {a}
Education: {b}
age: {c}
""".format(a=name, b=education, c=age)

print(card)
# Out:
# PIAIC card
# Student nam: Waleed khokhar
# Education: BSCS
# age: 20

# %%
name = "Waleed khokhar"
education = "BSCS"
age = 20

card = f"""
PIAIC card
Student nam: {name}
Education: {education}
Total: {20 + 5}
"""

print(card)
# Out:
# PIAIC card
# Student nam: Waleed khokhar
# Education: BSCS
# Total: 25

# %%
name = "           Waleed    "

print(name)              # "           Waleed    "
print(name.lstrip())     # "Waleed    "     (left stripped)
print(name.rstrip())     # "           Waleed"  (right stripped)
print(name.strip())      # "Waleed"         (both stripped)
# Out:
#            Waleed
# Waleed
#            Waleed
# Waleed

# %% [markdown]
# name = "Waleed khokhar"
# education = "BSCS"
# age = 20
#
# card = f"""
# PIAIC card
# Student nam: {name}
# Education: {education}
# Total: {20 + 5}
# """
#
# print(card)

# %% [markdown]
# """ triple single quotation

# %%
card : str =f""" 
PIAIc card: {name} 
father bna: {name} 
age: {age}
uni :{education} 
"""
print(card)
# Out:
#
# PIAIc card: Waleed
# father bna: Waleed
# age: 20
# uni :UNiverstity

# %%
import re

name = "          Waleed  Khokhar          "

print(name)  # "          Waleed  Khokhar          "

# Remove 9+ spaces
name1 = re.sub(' {9,90}', '', name)
print(name1)  # "Waleed  Khokhar"
# Out:
#           Waleed  Khokhar
# Waleed  Khokhar

# %% [markdown]
# f-sting  & jinja style

# %%
first_name = "ada"
lastname = "Loveplace"

fullname = f"{first_name} {lastname}"
print(fullname)                          # ada Loveplace

print(f"hello, {fullname}")              # hello, ada Loveplace

messg = f"hello, {fullname.title()}!"    # .title() inside f-string!
print(messg)                             # hello, Ada Loveplace!
# Out:
# ada Loveplace
# hello, ada Loveplace
# hello, Ada Loveplace!

# %%
card : str =f""" 
PIAIc card: {name}
father bna: {name}
age: {age}
total {12 + 8 + 5}
"""
print(card)
# Out:
#
# PIAIc card: Muhammad Qadun
# father bna: Muhammad Qadun
# age: 20
# total 25

# %%
[i for i in dir(str)  if "__" not in i]
# Out:
# ['capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# Print in diffrent formats

# %%
name : str = "Waleed Khooookhar"

print(name.capitalize())
print(name.lower())
print(name.title())
# Out:
# Waleed khooookhar
# waleed khooookhar
# Waleed Khooookhar

# %%
[i for i in dir(str) if "_" not in i]
# Out:
# ['capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
a = 5
b = 10
# {} place holder
"pakistani value a = {} and value b = {}".format(a,b)
# Out:
# 'pakistani value a = 5 and value b = 10'

# %% [markdown]
# complete

# %%
name : str = "Waleed khokhar"
education: str = "BSCS"
age : int = 20

card : str = f"""
PIAIC card
Student nam: {name}
Education: {education}
 total { 20 + 5}
"""
print(card)
# Out:
# PIAIC card
# Student nam: Waleed khokhar
# Education: BSCS
#  total 25

# %%
name : str = "Waleed khokhar"
education: str = "BSCS"
age : int = 20

card : str = """
PIAIC card
Student nam: {a}
Education: {b}
age: {c}
""".format(a=name, b=education, c=age)
#         0       1        2..
print(card)
# Out:
# PIAIC card
# Student nam: Waleed khokhar
# Education: BSCS
# age: 20

# %%
name : str = "Waleed khokhar"
education: str = "BSCS"
age : int = 20

card : str = """
PIAIC card
Student nam: {0}
Education: {2}
""".format(name, education, age)
#         0       1        2..
print(card)
# Out:
# PIAIC card
# Student nam: Waleed khokhar
# Education: 20

# %%
student : str = """"
print("My name is Waleed Khokhar")
a:int = 5
b:int = 8
print(a+b)
"""

exec(student)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Waleed Khokhar\anaconda3\envs\pythooon\Lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[15], line 8
#     exec(student)
#
#   File <string>:1
#     "
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Explore strings methods and attributes

# %%
[i for i in dir(str) if "_" not in i]
# Out:
# ['capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
a: list[str] = [i for i in dir(str) if "_" not in i]
print(a)
print(len(a))
# Out:
# ['capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# 46

# %% [markdown]
# predefined functions or global functions
#  print
#  type
#  id
#  dir
#  len

# %%
name : str = "Waleed"
print(name)
print(name.lower())
# Out:
# Waleed
# waleed

# %%
name: str = "                        Waleed"
print(name)
print(name.lstrip())
# Out:
#                         Waleed
# Waleed

# %%
name: str = "           Waleed    "
display(name)
display(name.lstrip())
display(name.rstrip())
display(name.strip())
# Out:
# '           Waleed    '
# 'Waleed    '
# '           Waleed'
# 'Waleed'

# %%
name: str = "           Waleed   KhokhR "
display(name)
name : str = re.sub(' {2,100}',' ', name)
display(name)
# Out:
# '           Waleed   KhokhR '
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 name: str = "           Waleed   KhokhR "
#       2 display(name)
# ----> 3 name : str = re.sub(' {2,100}',' ', name)
#       4 display(name)
#
# NameError: name 're' is not defined

# %%
import re
name: str = "          Waleed  Khokhar          "

print(name)
name1 : str = re.sub(' {9,90}', '', name)
display(name1)
# Out:
#           Waleed  Khokhar
# 'Waleed  Khokhar'

# %%
first_name = "ada"
lastname = "Loveplace"
fullname = f"{first_name} {lastname}"
print(fullname)
print(f"hello, {fullname}")
messg =f"hello, {fullname.title()}!"
print(messg)
# Out:
# ada Loveplace
# hello, ada Loveplace
# hello, Ada Loveplace!

# %% [markdown]
# \n
# \b
# \t

# %%
print("Name:\n Waleed")
print("Name:\t Waleed")
print("Name:\b Waleed")
# Out:
# Name:
#  Waleed
# Name:	 Waleed
# Name Waleed

# %%
nostarch_url:str = 'https://nostarch.com'
nostarch_url.removeprefix('http')
# Out:
# 's://nostarch.com'

# %% [markdown]
# ## 📋 What I Did in Class 2 (Summary)
#
# ### 🗓️ Date: January 2, 2024
#
# ---
#
# ### 1️⃣ Created Strings (4 Ways)
# ```python
# s1 = 'single quotes'
# s2 = "double quotes"
# s3 = '''triple single quotes'''
# s4 = """triple double quotes"""
# ```
#
# ### 2️⃣ Explored String Properties
# ```python
# name : str = "pakistan"
# print(name)                # pakistan
# print(type(name))          # <class 'str'>
# print(id(name))            # memory address
# print([i for i in dir(name) if "__" not in i])  # 46 methods
# ```
#
# ### 3️⃣ Learned String Methods
# ```python
# name = "Waleed Khooookhar"
# print(name.capitalize())   # Waleed khooookhar
# print(name.lower())        # waleed khooookhar
# print(name.title())        # Waleed Khooookhar
# ```
#
# ### 4️⃣ Practiced 3 Formatting Ways
#
# **a) Concatenation (`+`):**
# ```python
# name = "Waleed"
# age = 20
# card = "Name: " + name + "\nAge: " + str(age)
# ```
#
# **b) `.format()`:**
# ```python
# card = """
# Name: {a}
# Age: {b}
# """.format(a=name, b=age)
# ```
#
# **c) f-strings (BEST):**
# ```python
# card = f"""
# Name: {name}
# Total: {20 + 5}
# """
# ```
#
# ### 5️⃣ Handled Whitespace
# ```python
# name = "           Waleed    "
# print(name.lstrip())   # left stripped
# print(name.rstrip())   # right stripped
# print(name.strip())    # both stripped
# ```
#
# ### 6️⃣ Used Regex to Clean Spaces
# ```python
# import re
# name1 = re.sub(' {9,90}', '', name)
# ```
#
# ### 7️⃣ Learned Escape Characters
#
# | Escape | Meaning |
# |--------|---------|
# | `\n` | New line |
# | `\t` | Tab |
# | `\b` | Backspace |
#
# ```python
# print("Name:\n Waleed")   # new line
# print("Name:\t Waleed")   # tab
# print("Name:\b Waleed")   # backspace
# ```
#
# ### 8️⃣ Real-World f-string Example
# ```python
# first_name = "ada"
# lastname = "Loveplace"
# fullname = f"{first_name} {lastname}"
# print(f"hello, {fullname.title()}!")   # hello, Ada Loveplace!
# ```
#
# ### 9️⃣ Used `removeprefix()`
# ```python
# nostarch_url = 'https://nostarch.com'
# print(nostarch_url.removeprefix('http'))   # s://nostarch.com
# ```
#
# ### 🔟 Counted String Methods
# ```python
# a : list[str] = [i for i in dir(str) if "_" not in i]
# print(len(a))   # 46 methods
# ```
#
# ---
#
# ## 🧠 Predefined (Global) Functions Used
#
# | Function | Purpose |
# |----------|---------|
# | `print()` | Show output |
# | `type()` | Show data type |
# | `id()` | Show memory address |
# | `dir()` | List all methods |
# | `len()` | Count items |
# | `str()` | Convert to string |
# | `int()` | Convert to integer |
#
# ---
#
# ## ✅ Key Takeaways
#
# - ✅ Strings have **46 built-in methods**
# - ✅ **f-strings** are the best formatting way
# - ✅ `str()` converts numbers to strings for concatenation
# - ✅ `strip()` cleans whitespace — great for user input
# - ✅ Escape chars `\n`, `\t` help format output
# - ✅ Cannot concatenate `str` + `int` directly
#
# ---
#
# ## 📝 Practice Exercises Completed
#
# 1. ✅ Created strings with full name
# 2. ✅ Printed in title case
# 3. ✅ Cleaned messy strings with extra spaces
# 4. ✅ Used f-string for bio card
# 5. ✅ Printed multi-line address with `\n`
# 6. ✅ Removed `https://` prefix from URL
#
# ---
#
# **📅 Date:** January 2, 2024
# **🎯 Goal:** AI Engineer
# **⭐ Star this repo if it helps you!**
#
# > *"Strings are the backbone of every program. Master them first."*
